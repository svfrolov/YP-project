# %% [markdown]
# <a href="https://colab.research.google.com/github/svfrolov/YP-project/blob/main/%E2%84%969_%D0%92%D0%BE%D1%81%D1%81%D1%82%D0%B0%D0%BD%D0%BE%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B7%D0%BE%D0%BB%D0%BE%D1%82%D0%B0_%D0%B8%D0%B7_%D1%80%D1%83%D0%B4%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Проверим-вычисление-эффективности-обогащения" data-toc-modified-id="Проверим-вычисление-эффективности-обогащения-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Проверим вычисление эффективности обогащения</a></span></li><li><span><a href="#Признаки,-недоступные-в-тестовой-выборке" data-toc-modified-id="Признаки,-недоступные-в-тестовой-выборке-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Признаки, недоступные в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследуем-изменение-концентрации-элементов-на-каждом-этапе" data-toc-modified-id="Исследуем-изменение-концентрации-элементов-на-каждом-этапе-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исследуем изменение концентрации элементов на каждом этапе</a></span></li><li><span><a href="#Проанализируем-распределения-размеров-гранул-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Проанализируем-распределения-размеров-гранул-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проанализируем распределения размеров гранул на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследуем-суммарные-концентрации" data-toc-modified-id="Исследуем-суммарные-концентрации-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуем суммарные концентрации</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишем-функцию-для-вычисления-итогового-sMAPE" data-toc-modified-id="Напишем-функцию-для-вычисления-итогового-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишем функцию для вычисления итогового sMAPE</a></span></li><li><span><a href="#Обучим-и-проверим-несколько-моделей" data-toc-modified-id="Обучим-и-проверим-несколько-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучим и проверим несколько моделей</a></span><ul class="toc-item"><li><span><a href="#Сначала-подготовим-данные" data-toc-modified-id="Сначала-подготовим-данные-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Сначала подготовим данные</a></span></li><li><span><a href="#Разделим-признаки" data-toc-modified-id="Разделим-признаки-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Разделим признаки</a></span></li></ul></li><li><span><a href="#Выбрана-лучшая-модель,-её-качество-проверяем-на-тестовой-выборке" data-toc-modified-id="Выбрана-лучшая-модель,-её-качество-проверяем-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Выбрана лучшая модель, её качество проверяем на тестовой выборке</a></span><ul class="toc-item"><li><span><a href="#Тестовая-выборка" data-toc-modified-id="Тестовая-выборка-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Тестовая выборка</a></span></li></ul></li></ul></li><li><span><a href="#В-качестве-константной-модели-используем-DummyRegressor" data-toc-modified-id="В-качестве-константной-модели-используем-DummyRegressor-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>В качестве константной модели используем DummyRegressor</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовим прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Необходимо:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# Технологический процесс:
#
# Как золото получают из руды?
#
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#
#  ![viruchka_1576238830.jpg](attachment:viruchka_1576238830.jpg)
#
# Опишем каждую стадию:
# 1. Флотация
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# 2. Очистка
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
# Технологический процесс
#
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate **— ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
# - Параметры этапов
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
#
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
#
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
# - Возможные значения для блока [тип_параметра]:
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# Данные находятся в трёх файлах:
# - gold_recovery_train_new.csv — обучающая выборка;
# - gold_recovery_test_new.csv — тестовая выборка;
# - gold_recovery_full_new.csv — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# 1. Подготовим данные
# 1.1 Откроем и изучим файлы.
# Путь к файлам:
# - /datasets/gold_recovery_train_new.csv. Скачать датасет
# - /datasets/gold_recovery_test_new.csv. Скачать датасет
# - /datasets/gold_recovery_full_new.csv. Скачать датасет
#
# 1.2 Проверим, что эффективность обогащения рассчитана правильно.
#
# Расчёт эффективности
#
# Необходимо смоделировать процесс восстановления золота из золотосодержащей руды.
#
# Эффективность обогащения рассчитывается по формуле:
#  ![image-3.png](attachment:image-3.png)
#
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.
#
# Вычислим её на обучающей выборке для признака **rougher.output.recovery.** Найдём MAE между нашими расчётами и значением признака.
# 1.3 Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
# 1.4 Проведём предобработку данных.
#
# 2. Проанализируем данные
# 2.1 Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.
# 2.2 Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
# 2.3 Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
# 3. Построим модель
# 3.1 Напишем функцию для вычисления итоговой sMAPE.
# 3.2 Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.
#
#
# Метрика качества
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# Формула метрики качества:
#
#  ![image.png](attachment:image.png)
#
# Нужно спрогнозировать сразу две величины:
#
# 1. эффективность обогащения чернового концентрата rougher.output.recovery;
# 2. эффективность обогащения финального концентрата final.output.recovery;
#
# Итоговая метрика складывается из двух величин:
#
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Подготовка данных

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import make_scorer
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.dummy import DummyRegressor

import warnings
warnings.filterwarnings("ignore")

# %%
try:
    full = pd.read_csv('C:/Users/fs//Desktop/Проект.2/gold_recovery_full_new.csv') 
    train = pd.read_csv('C:/Users/fs//Desktop/Проект.2/gold_recovery_train_new.csv')
    test = pd.read_csv('C:/Users/fs//Desktop/Проект.2/gold_recovery_test_new.csv') 
except:
    full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
    train = pd.read_csv('/datasets/gold_recovery_train_new.csv') 
    test = pd.read_csv('/datasets/gold_recovery_test_new.csv')

# %%
train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
train.info()
print()
print("Дубликаты:", train.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
test.info()
print()
print("Дубликаты:", test.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
full.info()
print()
print("Дубликаты:", full.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# Данные подготовлены

# %% [markdown]
# ### Проверим вычисление эффективности обогащения

# %%
sig = ['rougher.output.concentrate_au', 'rougher.input.feed_au', 'rougher.output.tail_au', 'rougher.output.recovery']
df_test = train[sig].copy()

# %% [markdown]
# ![rec.jpg](attachment:rec.jpg)

# %%
C = df_test[sig[0]]
F = df_test[sig[1]]
T = df_test[sig[2]]

df_test['rougher.output.recovery.set'] = (C * (F - T)) / (F * (C - T)) * 100

# %%
df_test[['rougher.output.recovery', 'rougher.output.recovery.set']].head()
# Out:
#    rougher.output.recovery  rougher.output.recovery.set
# 0                87.107763                    87.107763
# 1                86.843261                    86.843261
# 2                86.842308                    86.842308
# 3                87.226430                    87.226430
# 4                86.688794                    86.688794

# %%
train_dropna = train.dropna(axis='index', subset=['rougher.output.recovery'])

# %%
train_rec = train_dropna['rougher.output.recovery']

# %%
MAE = mean_absolute_error(train_rec, df_test['rougher.output.recovery.set'])
print('MAE:', MAE)
# Out:
# MAE: 9.73512347450521e-15

# %% [markdown]
# Проверена формула вычисления эффективности обогащения, MAE маленькое - расчёт произведён верно

# %% [markdown]
# ### Признаки, недоступные в тестовой выборке

# %% [markdown]
# Cмотрим отсутствующие признаки в test

# %%
variance = set(train.columns) - set(test.columns)
train[variance].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 34 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.tail_au                                14149 non-null  float64
#  1   rougher.output.concentrate_sol                      14127 non-null  float64
#  2   primary_cleaner.output.tail_ag                      14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   rougher.calculation.floatbank11_sulfate_to_au_feed  14148 non-null  float64
#  5   final.output.concentrate_pb                         14148 non-null  float64
#  6   rougher.calculation.sulfate_to_au_concentrate       14148 non-null  float64
#  7   rougher.output.tail_sol                             14149 non-null  float64
# ...

# %% [markdown]
# В тестовой отсутствуют важные признаки (34 признака)
#
# в test добавим целевые из full

# %% [markdown]
# **Некоторые параметры недоступны, потому что замеряются или рассчитываются значительно позже. Из-за этого в test выборке отсутствуют некоторые признаки, которые могут быть в train. Также в тестовом наборе нет целевых признаков.**

# %% [markdown]
# ### Предобработка данных

# %%
test.describe()
# Out:
#        primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# count                    5286.000000                       5285.000000
# mean                      174.839652                          8.683596
# std                        43.027080                          3.072050
# min                         2.566156                          0.003839
# 25%                       147.121401                          6.489555
# 50%                       177.828489                          8.052207
# 75%                       208.125438                         10.027764
# max                       265.983123                         40.000000
#
#        primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# count                      5290.000000                     5286.000000
# mean                          7.266339                        1.383803
# std                           0.610219                        0.643474
# ...

# %%
train.describe()
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 14148.000000                 14148.000000
# mean                      5.142034                    10.132960
# std                       1.369586                     1.654930
# min                       0.000000                     0.000000
# 25%                       4.211620                     9.297355
# 50%                       4.994652                    10.297144
# 75%                       5.859540                    11.170603
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  13938.000000                 14149.000000
# mean                       9.202849                    44.003792
# std                        2.790516                     4.905261
# min                        0.000000                     0.000000
# ...

# %% [markdown]
# Смотрим количество пропусков

# %%
for dataset in [full, train, test]:
    print(dataset.isna().sum()[dataset.isna().sum()!=0].sort_values(ascending=False))
    print('**************************************************')
    print()
# Out:
# secondary_cleaner.output.tail_sol             1748
# rougher.input.floatbank11_xanthate             453
# rougher.state.floatbank10_e_air                436
# primary_cleaner.output.concentrate_sol         370
# secondary_cleaner.state.floatbank2_a_air       220
#                                               ...
# primary_cleaner.state.floatbank8_c_level         1
# primary_cleaner.state.floatbank8_b_level         1
# primary_cleaner.state.floatbank8_a_level         1
# final.output.tail_ag                             1
# secondary_cleaner.state.floatbank6_a_level       1
# Length: 63, dtype: int64
# **************************************************
#
# secondary_cleaner.output.tail_sol             1605
# rougher.state.floatbank10_e_air                436
# rougher.input.floatbank11_xanthate             428
# primary_cleaner.output.concentrate_sol         286
# secondary_cleaner.state.floatbank2_a_air       217
#                                               ...
# ...

# %% [markdown]
# Заменим NaN методом ffill

# %%
full = full.fillna(method = 'ffill')
train = train.fillna(method = 'ffill')
test = test.fillna(method = 'ffill')
print(full.isna().sum().unique()) 
print(train.isna().sum().unique())
print(test.isna().sum().unique())
# Out:
# [0]
# [0]
# [0]

# %% [markdown]
# Добавим из full в test_index_j

# %%
test_index_j = test.join(full[['rougher.output.recovery', 'final.output.recovery']])
test_index_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 55 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5290 non-null   float64
#  2   primary_cleaner.input.depressant            5290 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %% [markdown]
# train_index_g

# %%
train_index_g = train.drop(variance, axis=1)
train_index_g = train_index_g.join(train[['rougher.output.recovery', 'final.output.recovery']])

# %%
train_index_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 55 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        14149 non-null  object
#  1   primary_cleaner.input.sulfate               14149 non-null  float64
#  2   primary_cleaner.input.depressant            14149 non-null  float64
#  3   primary_cleaner.input.feed_size             14149 non-null  float64
#  4   primary_cleaner.input.xanthate              14149 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_air      14149 non-null  float64
#  6   primary_cleaner.state.floatbank8_a_level    14149 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_air      14149 non-null  float64
#  8   primary_cleaner.state.floatbank8_b_level    14149 non-null  float64
# ...

# %% [markdown]
# Проверим столбцы обучающей и тестовой выборки

# %%
train_index_g.shape[1], test_index_j.shape[1]
# Out:
# (55, 55)

# %% [markdown]
# Вывод:
# - были пропущенные значения
# - заменили методом fill
# - МАЕ считаем точным минимальное значение ошибки
# - в test добавили признаки из full
# - удалили разницу признаков

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследуем изменение концентрации элементов на каждом этапе

# %%
conc_stage = {'au':['rougher.input.feed_au', 'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au'],
                'ag':['rougher.input.feed_ag', 'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag'], 
                'pb':['rougher.input.feed_pb', 'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb'],}
 
for i in conc_stage:
    plt.figure(figsize=(15, 10))
    sns.boxplot(data = full[conc_stage[i]], palette='rainbow')
    plt.ylabel('Концентрация')
    plt.xlabel('Стадии')
    plt.title(f'Распределение значений доли материала {i} в концентрате на разных этапах ')
    plt.grid(True)
    plt.show()

# %% [markdown]
# - Золото растёт от этапа к этапу, хороший показатель
# - Серебро падает от этапа к этапу
# - Свинец растёт, но очень медленным темпом

# %% [markdown]
# ### Проанализируем распределения размеров гранул на обучающей и тестовой выборках

# %%
plt.figure(figsize=[20,10])
sn.kdeplot(train['rougher.input.feed_size'], color='green', label = 'train')
sn.kdeplot(test['rougher.input.feed_size'], color='blue', label = 'test')

plt.xlabel("Размер гранул сырья")
plt.ylabel("Плотность")
plt.legend(loc='upper left', prop={'size': 20},)
plt.grid(True)
plt.xlim(20,150)
plt.title("Распределениt гранул train, test на этапе флотации")
plt.show()

# %%
plt.figure(figsize=[20,10])
sn.kdeplot(train['primary_cleaner.input.feed_size'], color='green',label = 'train')
sn.kdeplot(test['primary_cleaner.input.feed_size'], color='blue',label = 'test')

plt.xlabel("Размер гранул сырья")
plt.ylabel("Плотность")
plt.legend(loc='upper left', prop={'size': 20},)
plt.grid(True)
plt.xlim(4,12)
plt.title("Распределениt гранул на этапе первичной очистки")
plt.show()

# %% [markdown]
# Распределение нормальное, наложение практически друг на друга

# %% [markdown]
# ### Исследуем суммарные концентрации

# %% [markdown]
# удалим из full

# %%
conc_sum = pd.DataFrame()

# %%
conc_sum['rougher.input'] = (full['rougher.input.feed_au']
                             + full['rougher.input.feed_ag']
                             + full['rougher.input.feed_pb'])
conc_sum['rougher.output'] = (full['rougher.output.concentrate_au']
                             + full['rougher.output.concentrate_ag']
                             + full['rougher.output.concentrate_pb'])
conc_sum['primary_cleaner.output'] = (full['primary_cleaner.output.concentrate_au'] 
                                      + full['primary_cleaner.output.concentrate_ag']
                                      + full['primary_cleaner.output.concentrate_pb'])
conc_sum['final.output'] = (full['final.output.concentrate_au']
                           + full['final.output.concentrate_ag']
                           + full['final.output.concentrate_pb'])

# %%
conc_sum.describe()
# Out:
#        rougher.input  rougher.output  primary_cleaner.output  final.output
# count   19439.000000    19439.000000            19439.000000  19439.000000
# mean       20.646120       39.373032               50.372125     59.223721
# std         4.480027        6.863389                7.628095      6.095138
# min         0.030000        0.000000                0.000000      0.000000
# 25%        17.252879       38.394639               50.053899     59.298323
# 50%        20.141216       40.312648               51.909156     60.306921
# 75%        23.797381       42.365102               53.386898     61.096667
# max        33.498784       55.568687               60.269003     64.968881

# %% [markdown]
# Посмотрим естьли NaN

# %%
conc_sum.isnull().sum()
# Out:
# rougher.input             0
# rougher.output            0
# primary_cleaner.output    0
# final.output              0
# dtype: int64

# %%
conc_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   rougher.input           19439 non-null  float64
#  1   rougher.output          19439 non-null  float64
#  2   primary_cleaner.output  19439 non-null  float64
#  3   final.output            19439 non-null  float64
# dtypes: float64(4)
# memory usage: 607.6 KB

# %%
conc_sum_ri = conc_sum['rougher.input']
conc_sum_ro = conc_sum['rougher.output']
conc_sum_po = conc_sum['primary_cleaner.output']
conc_sum_fo = conc_sum['final.output']

# %%
plt.figure(figsize=[20,10])
plt.xlim()

sns.distplot(conc_sum_ri, color='blue',label = 'final.input')
sns.distplot(conc_sum_ro, color='yellow',label = 'rougher.output')
sns.distplot(conc_sum_po, color='green',label = 'primary_cleaner.output')
sns.distplot(conc_sum_fo, color='red',label = 'final.output')

plt.legend(loc='upper left')
plt.grid(True)
plt.title("Распределениt гранул на разных стадиях")
plt.xlabel('Суммарная концентрация')
plt.ylabel('Плотность')
plt.show()

# %% [markdown]
# В суммарной концентрации были аномалии у 0, были убраны
#
# Есть выбросы у ноля, не содержат нужных веществ, удалим их

# %% [markdown]
# SMAPE плохо работает в окрестности нуля.
#
# https://habr.com/ru/company/zyfra/blog/678134/

# %% [markdown]
# Вывод:
#
# 1. В ходе анализа суммарных концентраций, мы нашли аномалии в районе ноля. Решили избавиться от таких объектов.
#
# 2. Выборки почистим от аномалий

# %%
train = train[(train['rougher.input.feed_ag'] >= 1) &
            (train['rougher.input.feed_pb'] >= 1) &
            (train['rougher.input.feed_sol'] >= 1) &
            (train['rougher.input.feed_au'] >= 1) &
            (train['rougher.output.concentrate_ag'] >= 1) &
            (train['rougher.output.concentrate_pb'] >= 1) &
            (train['rougher.output.concentrate_sol'] >= 1) &
            (train['rougher.output.concentrate_au'] >= 1) &
            (train['primary_cleaner.output.concentrate_ag'] >= 1) &
            (train['primary_cleaner.output.concentrate_pb'] >= 1) &
            (train['primary_cleaner.output.concentrate_sol'] >= 1) &
            (train['primary_cleaner.output.concentrate_au'] >= 1) &
            (train['final.output.concentrate_ag'] >= 1) &
            (train['final.output.concentrate_pb'] >= 1) &
            (train['final.output.concentrate_sol'] >= 1) &
            (train['final.output.concentrate_au'] >= 1)]

# %%
plt.figure(figsize=[20,10])
plt.xlim()

sns.distplot(conc_sum_ri, color='blue',label = 'final.input')
sns.distplot(conc_sum_ro, color='yellow',label = 'rougher.output')
sns.distplot(conc_sum_po, color='green',label = 'primary_cleaner.output')
sns.distplot(conc_sum_fo, color='red',label = 'final.output')

plt.legend(loc='upper left')
plt.grid(True)
plt.title("Распределение гранул перед первичной очисткой")
plt.xlabel('Суммарная концентрация')
plt.ylabel('Плотность')
plt.show()

# %% [markdown]
# Вывод:
#
# Проранализировав данные выяснили, что -
# - Концентрация элементов на каждом этапе
#   - Золото растёт от этапа к этапу, хороший показатель
#   - Серебро падает от этапа к этапу
#   - Свинец растёт, но очень медленным темпом
#
# - Проанализировали распределение размеров гранул на обучающей и тестовой выборках
#   - распределение нормальное, смещено влево
#   - перед первичной очисткой нормальное распределение
# - Исследовали суммарные концентрации
#   - в суммарной концентрации были выбросы, избавились от них

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишем функцию для вычисления итогового sMAPE

# %%
def sMAPE(target, predictions):
    smape = np.mean(np.abs(target - predictions) / ((np.abs(target) + np.abs(predictions)) / 2)) * 100
    return smape

# %%
def sMAPE_f(target, predictions):
    target_rougher = target['rougher.output.recovery']
    target_final = target['final.output.recovery']
    predictions_rougher = predictions[:, 0]
    predictions_final = predictions[:, 1]
    return 0.25 * sMAPE(target_rougher, predictions_rougher) + 0.75 * sMAPE(target_final, predictions_final)

# %%
custom_score = make_scorer(sMAPE_f, greater_is_better=False)

# %% [markdown]
# ### Обучим и проверим несколько моделей

# %% [markdown]
# #### Сначала подготовим данные

# %%
train.shape
# Out:
# (13304, 87)

# %%
train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# #### Разделим признаки

# %%
features_train = train_index_g.drop(columns=['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)
target_train = train_index_g[['rougher.output.recovery', 'final.output.recovery']]

features_test = test_index_j.drop(columns=['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)
target_test = test_index_j[['rougher.output.recovery', 'final.output.recovery']]

# %%
print(features_train.shape)
print(target_train.shape)
print(features_test.shape)
print(target_test.shape)
# Out:
# (14149, 52)
# (14149, 2)
# (5290, 52)
# (5290, 2)

# %%
param_gscv_lr = {
    'normalize': [False, True],
    'fit_intercept': [True, False],
    'copy_X': [False, True],
    'n_jobs': [-1, 1, 2]
}

lr = LinearRegression()
gscv_lr = GridSearchCV(estimator=lr, param_grid=param_gscv_lr, scoring=custom_score, verbose=10, cv=5)
gscv_lr.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False
# [CV 1/5; 1/24] END copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False; total time=   0.3s
# [CV 2/5; 1/24] START copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False
# [CV 2/5; 1/24] END copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False; total time=   0.2s
# [CV 3/5; 1/24] START copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False
# [CV 3/5; 1/24] END copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False; total time=   0.3s
# [CV 4/5; 1/24] START copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False
# [CV 4/5; 1/24] END copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False; total time=   0.2s
# [CV 5/5; 1/24] START copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False
# [CV 5/5; 1/24] END copy_X=False, fit_intercept=True, n_jobs=-1, normalize=False; total time=   0.3s
# ...

# %%
print("Лучшее значение sMAPE для модели LinearRegression:", -gscv_lr.best_score_.round(2))
print("\nПараметры модели:", gscv_lr.best_params_)
# Out:
# Лучшее значение sMAPE для модели LinearRegression: 12.32
#
# Параметры модели: {'copy_X': False, 'fit_intercept': False, 'n_jobs': -1, 'normalize': False}

# %%
param_gscv_dt = {'max_depth': range(1, 6)}

dt = DecisionTreeRegressor(random_state=12345)

gscv_dt = GridSearchCV(estimator=dt, param_grid=param_gscv_dt, scoring=custom_score, verbose=10, cv=5)
gscv_dt.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5; 1/5] START max_depth=1.................................................
# [CV 1/5; 1/5] END ...............................max_depth=1; total time=   0.1s
# [CV 2/5; 1/5] START max_depth=1.................................................
# [CV 2/5; 1/5] END ...............................max_depth=1; total time=   0.1s
# [CV 3/5; 1/5] START max_depth=1.................................................
# [CV 3/5; 1/5] END ...............................max_depth=1; total time=   0.1s
# [CV 4/5; 1/5] START max_depth=1.................................................
# [CV 4/5; 1/5] END ...............................max_depth=1; total time=   0.1s
# [CV 5/5; 1/5] START max_depth=1.................................................
# [CV 5/5; 1/5] END ...............................max_depth=1; total time=   0.1s
# [CV 1/5; 2/5] START max_depth=2.................................................
# ...

# %%
print("Лучшее значение smape для DecisionTreeRegressor:", -gscv_dt.best_score_.round(2),
      "\nЛучшая модель:", gscv_dt.best_params_)
# Out:
# Лучшее значение smape для DecisionTreeRegressor: 10.95
# Лучшая модель: {'max_depth': 5}

# %%
param_grid_kn = {
    'n_neighbors': [1, 5, 12],
    'weights': ['uniform', 'distance']
}

kn = KNeighborsRegressor()
gscv_kn_f = GridSearchCV(estimator=kn, param_grid=param_grid_kn, scoring=custom_score, cv=5, verbose=10)
gscv_kn_f.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START n_neighbors=1, weights=uniform..............................
# [CV 1/5; 1/6] END ............n_neighbors=1, weights=uniform; total time=   1.0s
# [CV 2/5; 1/6] START n_neighbors=1, weights=uniform..............................
# [CV 2/5; 1/6] END ............n_neighbors=1, weights=uniform; total time=   0.9s
# [CV 3/5; 1/6] START n_neighbors=1, weights=uniform..............................
# [CV 3/5; 1/6] END ............n_neighbors=1, weights=uniform; total time=   0.9s
# [CV 4/5; 1/6] START n_neighbors=1, weights=uniform..............................
# [CV 4/5; 1/6] END ............n_neighbors=1, weights=uniform; total time=   0.9s
# [CV 5/5; 1/6] START n_neighbors=1, weights=uniform..............................
# [CV 5/5; 1/6] END ............n_neighbors=1, weights=uniform; total time=   0.9s
# [CV 1/5; 2/6] START n_neighbors=1, weights=distance.............................
# ...

# %%
print("Лучшее значение sMAPE для модели KNeighborsRegressor:", -gscv_kn_f.best_score_.round(2))
print("\nПараметры модели:", gscv_kn_f.best_params_)
# Out:
# Лучшее значение sMAPE для модели KNeighborsRegressor: 14.0
#
# Параметры модели: {'n_neighbors': 12, 'weights': 'uniform'}

# %% [markdown]
# - Лучшее значение smape для DecisionTreeRegressor: 10.95
#
# - Лучшая модель: {'max_depth': 5}

# %% [markdown]
# ### Выбрана лучшая модель, её качество проверяем на тестовой выборке

# %% [markdown]
# #### Тестовая выборка

# %%
features_test = test_index_j.drop(['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)
target_test = test_index_j[['rougher.output.recovery', 'final.output.recovery']]

print(features_test.shape)
print(target_test.shape)
# Out:
# (5290, 52)
# (5290, 2)

# %%
model_best = DecisionTreeRegressor(random_state=12345, max_depth=1)
model_best.fit(features_train, target_train)
predicted_test = model_best.predict(features_test)
print('Значение sMAPE для LinearRegression на тестовой выборке:')
print(round(sMAPE_f(target_test, predicted_test), 2))
# Out:
# Значение sMAPE для LinearRegression на тестовой выборке:
# 11.37

# %% [markdown]
# ## В качестве константной модели используем DummyRegressor

# %%
dummy_r = DummyRegressor(strategy='median')
dummy_r.fit(features_train, target_train)
predicted_dummy = dummy_r.predict(features_test)

print('Значение метрики sMAPE на модели DummyRegressor:', round(sMAPE_f(target_test, predicted_dummy), 2))
# Out:
# Значение метрики sMAPE на модели DummyRegressor: 11.35

# %% [markdown]
# **Результат тестирования нашей модели на тествой выборке лучше, чем результат константной модели. Поэтому используем эту модель для предсказания**

# %% [markdown]
# **Общий вывод:**
#
# 1. Подготовлены данные, дубликаты не найдены
#
# 2. Проверка расчетов эффективности обогащения (МАЕ) показала, что данные расчетов корректны.
#
# 3. Сделали анализ признаков, в тестовой отсутствуют важные признаки (34 признака)
#
# 4. Провели предобработку данных, заполнили пустые значения, заменили NaN, в test добавили признаки из full, удалили разницу признаков
#
# 5. Золото растёт от этапа к этапу, хороший показатель, серебро падает от этапа к этапу, свинец растёт, но очень медленным темпом
#
# 6. в суммарной концентрации были аномалии у 0, были убраны
#
# 7. Написали функцию для вычисления итогового sMAPE
#
# 8. Обучили модели (LinearRegression, KNeighborsRegressor) лучшая модель LinearRegression:  12.38 с параметрами: {normalize=False}
#
# 9. Проверили её на тестовой выборке Значение sMAPE для LinearRegression на тестовой выборке: 13.91
#
# **Результат тестирования нашей модели LinearRegression на тествой выборке лучше, чем результат константной модели. Поэтому используем эту модель для предсказания**
